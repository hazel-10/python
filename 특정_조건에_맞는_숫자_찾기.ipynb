# %% [markdown]
# <a href="https://colab.research.google.com/github/hazel-10/python/blob/main/%ED%8A%B9%EC%A0%95_%EC%A1%B0%EA%B1%B4%EC%97%90_%EB%A7%9E%EB%8A%94_%EC%88%AB%EC%9E%90_%EC%B0%BE%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number=30
num_list=[]

# %%
for i in range(number+1):
    if i % 3 == 0 and i % 2 != 0:
            num_list.append(i)

# %%
print(num_list)
# Out:
# [3, 9, 15, 21, 27]

# %%
def solution(num):
    number_list=[]

    for i in range(num+1):
     if i % 3 == 0 and i % 2 != 0:
            number_list.append(i)

    return number_list

# %%
solution(30)
# Out:
# [3, 9, 15, 21, 27]

# %%
solution(123)
# Out:
# [3,
#  9,
#  15,
#  21,
#  27,
#  33,
#  39,
#  45,
#  51,
#  57,
#  63,
#  69,
#  75,
#  81,
#  87,
#  93,
#  99,
#  105,
#  111,
#  117,
#  123]
